# %% [markdown]
# # Embeddings

# %% [markdown]
# ### 向量相似度计算

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

from openai import OpenAI   # openai=1.10.0
client = OpenAI()

def cos_sim(a, b):
    """余弦距离 -- 越大越相似"""
    return dot(a, b)/(norm(a)*norm(b))
def l2(a, b):
    """欧式距离 -- 越小越相似"""
    x = np.asarray(a)-np.asarray(b)
    return norm(x)

def get_embeddings(texts, model="text-embedding-ada-002"):
    data = client.embeddings.create(input=texts, model=model).data
    return [x.embedding for x in data]

test_arr = ["我是一段测试文本"]
vs = get_embeddings(test_arr)[0]
print(vs[:10])
# print(len(vs))  # 1536


query = "国际争端"
documents = [
    "联合国就苏丹达尔富尔地区大规模暴力事件发出警告",
    "土耳其、芬兰、瑞典与北约代表将继续就瑞典“入约”问题进行谈判",
    "日本岐阜市陆上自卫队射击场内发生枪击事件 3人受伤",
    "我国首次在空间站开展舱外辐射生物学暴露实验",
    "国家游泳中心(水立方) : 恢复游泳、嬉水乐园等水上项目运营",
]

query_vec = get_embeddings([query])[0]
doc_vecs = get_embeddings(documents)
print("Cosine distance.")
print(cos_sim(query_vec, query_vec))
for vec in doc_vecs:
    print(cos_sim(query_vec, vec))

print("\nEuclidean distance:")
print(l2(query_vec, query_vec))
for vec in doc_vecs:
    print(l2(query_vec, vec))
# Out:
# [-0.02138707786798477, -0.010255279019474983, -0.001874403329566121, -0.008866332471370697, -0.017125843092799187, 0.0009591146954335272, -0.017247207462787628, 0.002894200151786208, -0.027590138837695122, -0.018312515690922737]
# Cosine distance.
# 1.0000000000000002
# 0.8220653393211526
# 0.8294946584302412
# 0.7978978814131463
# 0.7933096993158312
# 0.7660214052216155
#
# Euclidean distance:
# 0.0
# 0.5965478203204638
# 0.5839611825268289
# 0.6357705796658597
# 0.6429467960889444
# 0.684073960202615

# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: chromadb in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (0.4.24)
# Requirement already satisfied: build>=1.0.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.1.1)
# Requirement already satisfied: requests>=2.28 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (2.6.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.27.1)
# Requirement already satisfied: numpy>=1.22.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.17.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (6.1.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (1.62.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from chromadb) (3.9.15)
# Requirement already satisfied: packaging>=19.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (21.3)
# Requirement already satisfied: pyproject_hooks in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb) (6.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Requirement already satisfied: certifi>=14.05.14 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2022.9.14)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.4.1)
# Requirement already satisfied: requests-oauthlib in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.12)
# Requirement already satisfied: coloredlogs in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (4.21.12)
# Requirement already satisfied: sympy in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.1.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.7.2)
# Requirement already satisfied: monotonic>=1.5 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9->chromadb) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from tokenizers>=0.13.2->chromadb) (0.21.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from importlib-resources->chromadb) (3.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging>=19.0->build>=1.0.3->chromadb) (3.0.9)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)

# %% [markdown]
# ### 基于相似度聚类

# %%
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from sklearn.cluster import KMeans, DBSCAN
import numpy as np

texts = [
    "这个多少钱",
    "啥价",
    "给我报个价",
    "我要红色的",
    "不要了",
    "算了",
    "来红的吧",
    "作罢",
    "价格介绍一下",
    "红的这个给我吧"
]
model = OpenAIEmbeddings(model='text-embedding-ada-002')
X = []
for t in texts:
    embedding = model.embed_query(t)
    X.append(embedding)
    
#clusters = KMeans(n_clusters=3, random_state=42, n_init="auto").fit(X)
clusters = DBSCAN(eps=0.55, min_samples=2).fit(X)
for i,t in enumerate(texts):
    print("{}\t{}".format(clusters.labels_[i],t))
# Out:
# 0	这个多少钱
# 0	啥价
# 0	给我报个价
# 1	我要红色的
# -1	不要了
# -1	算了
# 1	来红的吧
# -1	作罢
# 0	价格介绍一下
# 1	红的这个给我吧

# %%
# !pip install -U langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting langchain-openai
#   Downloading https://mirrors.aliyun.com/pypi/packages/81/63/012be16114559243aabcc9ec570366df84591dc9f8f3c2349a398e9b3626/langchain_openai-0.0.8-py3-none-any.whl (32 kB)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.27 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.1.30)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (1.10.0)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.6.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (4.2.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (0.1.22)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.27->langchain-openai) (8.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.26.0)
# Requirement already satisfied: sniffio in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2023.12.25)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.27->langchain-openai) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.27->langchain-openai) (1.2.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.27->langchain-openai) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.27->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in /Users/zhanghui/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.27->langchain-openai) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.27->langchain-openai) (1.26.12)
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-0.0.8
